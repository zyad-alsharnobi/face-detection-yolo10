# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tpP123Hkw9lV5BfduRLb")
project = rf.workspace("objectdetection-dxeuw").project("face-detection-z1x9s")
version = project.version(1)
dataset = version.download("yolov11")

# %%
# %pip install ultralytics 
import ultralytics 
from ultralytics import YOLO
model = YOLO('yolov10n.pt')
ultralytics.checks()

# %%
def write_text_to_file(text, file_path):
    with open(file_path, 'w') as file:
        file.write(text)


text = """
train: /kaggle/working/face-detection-1/train/images
val: /kaggle/working/face-detection-1/test/images

nc: 2
names: ['Face', 'face']

roboflow:
  workspace: objectdetection-dxeuw
  project: face-detection-z1x9s
  version: 1
  license: CC BY 4.0
  url: https://universe.roboflow.com/objectdetection-dxeuw/face-detection-z1x9s/dataset/1

"""


write_text_to_file(text, '/kaggle/working/face-detection-1/data.yaml')

# %%
# !yolo task=detect mode=train data=/kaggle/working/face-detection-1/data.yaml model=yolov10n.pt epochs=30 imgsz=640 batch=16

# %%
from IPython.display import Image, display

# %%
display(Image(filename='/kaggle/working/runs/detect/train2/results.png',width = 1000))

# %%
display(Image(filename='/kaggle/working/runs/detect/train2/confusion_matrix.png',width=1000))

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/train2/weights/best.pt imgsz=640 conf=0.5 \
source=/kaggle/working/face-detection-1/test/images

# %%
from IPython.display import Image, display
import glob
i=0
for imageName in glob.glob('/kaggle/working/runs/detect/predict/*.jpg')[77:82]:
    display(Image(filename=imageName))
